# %%
import numpy as np
import matplotlib.pyplot as plt
from p1a import *
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
x = Nodes(100, "chebyshev")
plt.plot(x, np.zeros_like(x), ".")
A = build_A(x)

# %%
u = x*x
plt.plot(x, A@u)

# %%
b0 = 1; b2 = 0; b3 = 0; a1 = 1; a2 = 0; a3 = 0
